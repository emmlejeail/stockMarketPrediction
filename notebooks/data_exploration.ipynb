# %%
import numpy as np
import pandas as pd
import datetime as dt
import math
import seaborn as sns
import matplotlib.pyplot as plt
import glob

# %% [markdown]
# # Data Analysis and Exploration

# %%
#Import dataset
dataset = pd.read_csv("../data/csv/ACNB.csv", header=0)

dataset.head()
# Out:
#          Date        Low       Open  Volume       High      Close  \
# 0  04-04-1994  21.088434  21.088434     221  21.088434  21.088434
# 1  05-04-1994  21.088434  21.088434     441  21.088434  21.088434
# 2  06-04-1994  21.088434  21.315193    3528  21.541950  21.541950
# 3  07-04-1994  21.315193  21.541950    6615  21.541950  21.315193
# 4  08-04-1994  21.088434  21.315193    1103  21.315193  21.088434
#
#    Adjusted Close
# 0        6.602687
# 1        6.602687
# 2        6.744678
# 3        6.673684
# 4        6.602687

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7047 entries, 0 to 7046
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            7047 non-null   object
#  1   Low             7047 non-null   float64
#  2   Open            7047 non-null   float64
#  3   Volume          7047 non-null   int64
#  4   High            7047 non-null   float64
#  5   Close           7047 non-null   float64
#  6   Adjusted Close  7047 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 385.5+ KB

# %%
dataset.describe()
# Out:
#                Low         Open        Volume         High        Close  \
# count  7047.000000  7047.000000  7.047000e+03  7047.000000  7047.000000
# mean     20.162708    20.339520  4.656982e+03    20.525138    20.342179
# std       6.198113     6.311039  1.794015e+04     6.430576     6.313696
# min       7.200000     7.560000  0.000000e+00     8.500000     7.750000
# 25%      15.450000    15.638130  4.000000e+02    15.700000    15.600000
# 50%      18.594105    18.684807  1.700000e+03    18.820862    18.750000
# 75%      23.006134    23.129251  5.100000e+03    23.356009    23.174603
# max      40.119999    41.000000  1.186600e+06    41.450001    40.939999
#
#        Adjusted Close
# count     7047.000000
# mean        13.230466
# std          8.213081
# min          4.223916
# 25%          7.522855
# 50%          9.854819
# 75%         16.432393
# max         36.783699

# %%
#Drop lines with null values
dataset.dropna()
dataset.describe()
# Out:
#                Low         Open        Volume         High        Close  \
# count  7047.000000  7047.000000  7.047000e+03  7047.000000  7047.000000
# mean     20.162708    20.339520  4.656982e+03    20.525138    20.342179
# std       6.198113     6.311039  1.794015e+04     6.430576     6.313696
# min       7.200000     7.560000  0.000000e+00     8.500000     7.750000
# 25%      15.450000    15.638130  4.000000e+02    15.700000    15.600000
# 50%      18.594105    18.684807  1.700000e+03    18.820862    18.750000
# 75%      23.006134    23.129251  5.100000e+03    23.356009    23.174603
# max      40.119999    41.000000  1.186600e+06    41.450001    40.939999
#
#        Adjusted Close
# count     7047.000000
# mean        13.230466
# std          8.213081
# min          4.223916
# 25%          7.522855
# 50%          9.854819
# 75%         16.432393
# max         36.783699

# %%
dataset.plot(legend=True,subplots=True,figsize = (12,6))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>], dtype=object)
